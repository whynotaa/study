# %%
key = '+VNWs9eRHtfVOom9x6qojoca7bnMJO1fkfkbCGdwwZ/ARyiqjGkPgk0QEy6kk1AmQsqeOJskC65lg0E4fA0cjA=='

# %%
# https://www.data.go.kr/data/15073855/openapi.do
import requests
 
url = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
params ={'serviceKey' : "+VNWs9eRHtfVOom9x6qojoca7bnMJO1fkfkbCGdwwZ/ARyiqjGkPgk0QEy6kk1AmQsqeOJskC65lg0E4fA0cjA==", 'returnType' : 'json', 'numOfRows' : '100', 'pageNo' : '1', 'sidoName' : '서울', 'ver' : '1.0' }
 
response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"body":{"totalCount":40,"items":[{"so2Grade":"1","coFlag":null,"khaiValue":"85","so2Value":"0.004","coValue":"0.3","pm25Flag":null,"pm10Flag":null,"o3Grade":"2","pm10Value":"21","khaiGrade":"2","pm25Value":"13","sidoName":"\xec\x84\x9c\xec\x9a\xb8","no2Flag":null,"no2Grade":"1","o3Flag":null,"pm25Grade":"1","so2Flag":null,"dataTime":"2024-09-26 16:00","coGrade":"1","no2Value":"0.010","stationName":"\xec\xa4\x91\xea\xb5\xac","pm10Grade":"1","o3Value":"0.072"},{"so2Grade":"1","coFlag":null,"khaiValue":"91","so2Value":"0.003","coValue":"0.5","pm25Flag":null,"pm10Flag":null,"o3Grade":"2","pm10Value":"27","khaiGrade":"2","pm25Value":"16","sidoName":"\xec\x84\x9c\xec\x9a\xb8","no2Flag":null,"no2Grade":"1","o3Flag":null,"pm25Grade":"2","so2Flag":null,"dataTime":"2024-09-26 16:00","coGrade":"1","no2Value":"0.022","stationName":"\xed\x95\x9c\xea\xb0\x95\xeb\x8c\x80\xeb\xa1\x9c","pm10Grade":"1","o3Value":"0.079"},{"so2Grade":"1","coFlag":null,"khaiValue":"88","so2Value":"0.004","coValue":"0.3","pm25Flag":null,"pm10Flag":null,"o3Grade":"2","pm10Value":"24","khaiGrade":"2","pm25Value":"13","sidoName":"\xec\x84\x9c\xec\x9a\xb8","no2Flag":null,"no2Grade":"1","o3Flag":null,"pm25Grade":"1","so2Flag":null,"dataTime":"2024-09-26 16:00","coGrade":"1","no2Value":"0.015","stationName":"\xec\xa2\x85\xeb\xa1\x9c\xea\xb5\xac","pm10Grade":"1","o3Value":"0.075"},{"so2Grade":"1","coFlag":null,"khaiValue":"-","so2Value":"0.002","coValue":"0.4","pm25Flag":null,"pm10Flag":null,"o3Grade":"2","pm10Value":"37","khaiGrade":null,"pm25Value":"15","sidoName":"\xec\x84\x9c\xec\x9a\xb8","no2Flag":null,"no2Grade":"1","o3Flag":null,"pm25Grade":null,"so2Flag":null,"dataTime":"2024-09-26 16:00","coGrade":"1","no2Value":"0.021","stationName":"\xec\xb2\xad\xea\xb3\x84\xec\xb2\x9c\xeb\xa1\x9c","pm10Grade":null,"o3Value":"0.063"},{"so2Grade":"1","coFlag":null,"khaiValue":"81","so2Value":"0.003","coValue":"0.4","pm25Flag":null,"pm10Flag":null,"o3Grade":"2","pm10Value":"29","khaiGrade":"2","pm25Value":"14","sidoName":"\xec\x84\x9c\xec\x9a\xb8","no2Flag":null,"no2Grade":"1","o3Flag":null,"pm25Grade":"1","so2Flag":null,"dataTime":"2024-09-26 16:00","coGrade":"1","no2Value":"0.019","stationName":"\xec\xa2\x85\xeb\xa1\x9c","pm10Grade":"1","o3Value":"0.067"},{"so2Grade":"1","coFlag":null,"khaiValue":"79","so2Value":"0.003","coValue":"0.4","pm25Flag":null,"pm10Flag":null,"o3Grade":"2","pm10Value":"28","khaiGrade":"2","pm25Value":"17","sidoName":"\xec\x84\x9c\xec\x9a\xb8","no2Flag":null,"no2Grade":"1","o3Flag":null,"pm25Grade":"2","so2Flag":null,"dataTime":"2024-09-26 16:00","coGrade":"1","no2Value":"0.026","stationName":"\xec\x9a\xa9\xec\x82\xb0\xea\xb5\xac","pm10Grade":"1","o3Value":"0.064"},{"so2Grade":"1","coFlag":null,"khaiValue":"121","so2Value":"0.003","coValue":"0.7","pm25Flag":null,"pm10Flag":null,"o3Grade":"3","pm10Value":"24","khaiGrade":"3","pm25Value":"16","sidoName":"\xec\x84\x9c\xec\x9a\xb8","no2Flag":null,"no2Grade":"1","o3Flag":null,"pm25Grade":"1","so2Flag":null,"dataTime":"2024-09-26 16:00","coGrade":"1","no2Value":"0.018","stationName":"\xea\xb4\x91\xec\xa7\x84\xea\xb5\xac","pm10Grade":"1","o3Value":"0.098"},{"so2Grade":"1","coFlag":null,"khaiValue":"90","so2Value":"0.003","coValue":"0.3","pm25Flag":null,"pm10Flag":null,"o3Grade":"2","pm10Value":"27","khaiGrade":"2","pm25Value":"17","sidoName":"\xec\x84\x9c\xec\x9a\xb8","no2Flag":null,"no2Grade":"1","o3Flag":null,"pm25Grade":"2","so2Flag":null,"dataTime":"2024-09-26 16:00","coGrade":"1","no2Value":"0.022","stationName":"\xec\x84\xb1\xeb\x8f\x99\xea\xb5\xac","pm10Grade":"1","o3Value":"0.078"},{"so2Grade":"1","coFlag":null,"khaiValue":"-","so2Value":"0.003","coValue":"0.6","pm25Flag":null,"pm10Flag":null,"o3Grade":"2","pm10Value":"32","khaiGrade":null,"pm25Value":"15","sidoName":"\xec\x84\x9c\xec\x9a\xb8","no2Flag":null,"no2Grade":"2","o3Flag":null,"pm25Grade":null,"so2Flag":null,"dataTime":"2024-09-26 16:00","coGrade":"1","no2Value":"0.055","stationName":"\xea\xb0\x95\xeb\xb3\x80\xeb\xb6\x81\xeb\xa ...

# %%
import streamlit as st
import json
import requests
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain_community.chat_models import ChatOllama
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnableMap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import streamlit as st
#       2 import json
#       3 import requests
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
def main():
    st.title("대기질 정보 제공 챗봇")
    
    text_var = st.text_input("조사할 시도를 적어주세요.")
    
    clicked_button = st.button("제출")
    if clicked_button:
        result = seoul_pm_query(text_var)
        air_quality_info= parse_air_quality_data(result)
        st.write(f"{air_quality_info}")
        
        
if __name__ == "__main__":
    main()
